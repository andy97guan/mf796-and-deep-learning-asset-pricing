# %% [markdown]
# # Using SDF in Asset Pricing

# %% [markdown]
# ## 1. import relative package

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import time

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Input
from keras.layers import concatenate
from keras.optimizers import SGD
from keras.layers.core import Lambda
import keras.backend as K
from keras.optimizers import Adam
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2. import micro, macro and return data from local
# data comes from Wind.api

# %%
file = open('a1','rb')
dataset = pickle.load(file, encoding='utf-8')
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-dcb355fc9305> in <module>
# ----> 1 file = open('a1','rb')
#       2 dataset = pickle.load(file, encoding='utf-8')
#       3 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a1'

# %%
macro_data, micro_data, return_data = dataset
return_data = np.array(return_data)
macro_data.shape
# Out:
# (3233, 12, 15)

# %%
# dataset split
train_micro = micro_data[:2000, :, :]
train_macro = macro_data[:2000, :, :]
train_return = return_data[1:2001, :]

validation_micro = micro_data[2001:2600, :, :]
validation_macro = macro_data[2001:2600, :, :]
validation_return = return_data[2002:2601, :]

test_micro = micro_data[2601:-1, :, :]
test_macro = macro_data[2601:-1, :, :]
test_return = return_data[2602:, :]

# %% [markdown]
# ## 3. Training Process

# %% [markdown]
# #### 3.1 model parameters

# %%
# model parameter
ndays = train_micro.shape[0]
nstocks = train_micro.shape[1]
nmacro = train_macro.shape[2]
nmicro = train_micro.shape[2]
LSTM_delay = 12
n_g = 4

# %% [markdown]
# #### 3.2 SGD Network
#
# Including one LSTM to deal with Macro-variables with 4 hidden states，then the both the hidden states and the micro-variables go in to a 64-64-1 DNN. After that we are able to construct $M_{t+1}R_{t+1}$，and with the given $g$ function，we can calculate and minimize the MSE.

# %%
# SGD networks

# data loading
macro_in1 = Input(shape=(LSTM_delay, nmacro))
# macro_in1_1 = Lambda(lambda x:K.reshape(x, shape=(-1,1, nmacro)))(macro_in1)

micro_in1 = Input(shape=(nstocks,nmicro))

return_next_date1 = Input(shape=(nstocks,))


# LSTM
sgd_lstm_out = LSTM(4)(macro_in1) # (1000, 4)
sgd_lstm_out = Lambda(lambda x:K.repeat(x, nstocks))(sgd_lstm_out)


# SGD weights DNN
sgd_weights_input = concatenate([micro_in1, sgd_lstm_out]) # (1000, 50, 104)  

sgd_weights_output = Dense(64, activation='relu')(sgd_weights_input)
sgd_weights_output = Dense(64, activation='relu')(sgd_weights_input)
sgd_weights_output = Dense(1)(sgd_weights_input)
sgd_weights_output = Lambda(lambda x:K.reshape(x, shape=(-1, nstocks)))(sgd_weights_output)


# SGD construction
def construction(x):
    tmp = 1 - x[0] * x[1]
    tmp = K.sum(tmp, axis=1)
    tmp = K.reshape(tmp, shape=(-1,1)) # (1000, 1)
    tmp = K.repeat(tmp, nstocks) # (1000, 50, 1)
    tmp = K.reshape(tmp, shape=(-1,nstocks)) # (1000, 50)
    tmp = tmp * x[1] # (1000, 50)
    tmp = K.reshape(tmp, shape=(-1, nstocks, 1))
    return tmp # the M_{t+1}R_{t+1}

sgd_construction_ouput = Lambda(construction)([sgd_weights_output,return_next_date1])


# attain con_g_output from conditional network
con_g_output_loaded = Input(shape=(nstocks, n_g))


# combine those two and calculate loss
loss_function_w = Lambda(lambda x:x[0]*x[1])([sgd_construction_ouput, con_g_output_loaded]) # (1000,50, 8)
loss_function_w = Lambda(lambda x:K.reshape(x, shape=(-1, nstocks*n_g)))(loss_function_w)


# with weights output for validation and sgd output for condition network training
model_output_w = Model(inputs=[macro_in1, micro_in1], outputs=sgd_weights_output) # acquires weights given info
model_output_sgd = Model(inputs=[macro_in1, micro_in1, return_next_date1], outputs=sgd_construction_ouput) # acquires MR for condition networks


# SGD model compile
model_w = Model(inputs=[macro_in1, micro_in1, return_next_date1, con_g_output_loaded], outputs=loss_function_w)
model_w.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# #### 3.3 Conditional Neural Nets
#
# Including one LSTM for dealing with Macro-variables with 4 hidden states, then the hidden states and micro-variables goin to a 64-8 DNN，and finally with given $g$，we can calculate $M_{t+1}R_{t+1}$，and maximize the MSE.

# %%
# conditional networks

macro_in2 = Input(shape=(LSTM_delay, nmacro))

micro_in2 = Input(shape=(nstocks,nmicro))

sgd_construction_ouput_loaded = Input(shape=(nstocks,1))

con_lstm_out = LSTM(4)(macro_in2) # (1000, 4)
con_lstm_out = Lambda(lambda x:K.repeat(x, nstocks))(con_lstm_out)

con_weights_input = concatenate([micro_in2, con_lstm_out]) # (1000, 50, 104)  

con_g_output = Dense(64, activation='relu')(con_weights_input)
con_g_output = Dense(n_g)(con_g_output) # (1000, 50, 8)

loss_function_g = Lambda(lambda x:K.log(1/(1+K.abs(x[0]*x[1]))))([sgd_construction_ouput_loaded, con_g_output]) # (1000,50, 8)
loss_function_g = Lambda(lambda x:K.reshape(x, shape=(-1, nstocks*n_g)))(loss_function_g)

model_output_g = Model(inputs=[macro_in2, micro_in2], outputs=con_g_output) # acquires MR for condition networks

model_g = Model(inputs=[macro_in2, micro_in2, sgd_construction_ouput_loaded], outputs=loss_function_g)
model_g.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# #### 3.4 data training process

# %%
# data process
y_train = np.zeros((ndays, n_g*nstocks))
macro_in = train_macro
micro_in = train_micro
return_next_date = train_return
function_g = np.ones((ndays, nstocks, n_g))
sdf_loss = []

epoch = 200
batch_size = 200
n_iteration = 100

for i in range(n_iteration):
    t1 = time.time()

    # SDF nets
    history_w = model_w.fit([macro_in, micro_in, return_next_date, function_g], y_train, epochs=epoch, batch_size=batch_size, verbose=0)
    function_sgd = model_output_sgd.predict([macro_in, micro_in, return_next_date])
    sdf_loss = sdf_loss + history_w.history['loss'].copy() # save loss

    # conditional nets
    model_g.fit([macro_in, micro_in, function_sgd], y_train, epochs=epoch, batch_size=batch_size, verbose=0)
    function_g = model_output_g.predict([macro_in, micro_in])
    print('done with', i,',sdf loss is', sdf_loss[-1], ', using', round(time.time()-t1, 2), 'seconds')
# Out:
# done with 0 ,sdf loss is 4.00386917591095 , using 25.0 seconds
# done with 1 ,sdf loss is 0.40900575667619704 , using 22.82 seconds
# done with 2 ,sdf loss is 0.48293974101543424 , using 22.96 seconds
# done with 3 ,sdf loss is 0.14863735400140285 , using 23.03 seconds
# done with 4 ,sdf loss is 0.41671767383813857 , using 22.96 seconds
# done with 5 ,sdf loss is 0.17303299084305762 , using 22.84 seconds
# done with 6 ,sdf loss is 0.382203184068203 , using 22.78 seconds
# done with 7 ,sdf loss is 0.11152648106217385 , using 23.08 seconds
# done with 8 ,sdf loss is 0.2279350221157074 , using 23.42 seconds
# done with 9 ,sdf loss is 0.10060088448226452 , using 23.62 seconds
# done with 10 ,sdf loss is 0.14616846591234206 , using 23.4 seconds
# done with 11 ,sdf loss is 0.08754639364778996 , using 23.49 seconds
# done with 12 ,sdf loss is 0.1036766454577446 , using 24.02 seconds
# done with 13 ,sdf loss is 0.08052212484180928 , using 23.52 seconds
# done with 14 ,sdf loss is 0.2513004705309868 , using 23.61 seconds
# done with 15 ,sdf loss is 0.1861627995967865 , using 23.73 seconds
# done with 16 ,sdf loss is 0.1835800562053919 , using 23.64 seconds
# done with 17 ,sdf loss is 0.42074680551886556 , using 23.79 seconds
# done with 18 ,sdf loss is 0.08522598259150982 , using 23.77 seconds
# done with 19 ,sdf loss is 0.2674206383526325 , using 23.78 seconds
# done with 20 ,sdf loss is 0.08900495879352092 , using 23.89 seconds
# done with 21 ,sdf loss is 0.04040029738098383 , using 24.33 seconds
# done with 22 ,sdf loss is 0.10798110477626324 , using 24.27 seconds
# done with 23 ,sdf loss is 0.05702526886016131 , using 23.98 seconds
# done with 24 ,sdf loss is 0.09111278131604195 , using 24.07 seconds
# done with 25 ,sdf loss is 0.13529814146459102 , using 24.21 seconds
# done with 26 ,sdf loss is 0.028390531055629255 , using 23.9 seconds
# done with 27 ,sdf loss is 0.04012741912156344 , using 24.2 seconds
# done with 28 ,sdf loss is 0.07940466441214085 , using 23.92 seconds
# done with 29 ,sdf loss is 0.025917009636759757 , using 24.65 seconds
# done with 30 ,sdf loss is 0.033842568285763264 , using 25.3 seconds
# done with 31 ,sdf loss is 0.07227792106568813 , using 24.71 seconds
# done with 32 ,sdf loss is 0.05125852357596159 , using 24.56 seconds
# done with 33 ,sdf loss is 0.04013298414647579 , using 24.46 seconds
# done with 34 ,sdf loss is 0.06046273037791252 , using 24.62 seconds
# done with 35 ,sdf loss is 0.033436902426183225 , using 24.71 seconds
# done with 36 ,sdf loss is 0.03109874278306961 , using 24.56 seconds
# done with 37 ,sdf loss is 0.044924314692616464 , using 24.77 seconds
# done with 38 ,sdf loss is 0.007027828041464091 , using 24.64 seconds
# done with 39 ,sdf loss is 0.021218272391706705 , using 24.49 seconds
# done with 40 ,sdf loss is 0.04265843536704779 , using 24.59 seconds
# done with 41 ,sdf loss is 0.04784936383366585 , using 24.54 seconds
# done with 42 ,sdf loss is 0.02948291366919875 , using 24.69 seconds
# done with 43 ,sdf loss is 0.012934287544339895 , using 24.49 seconds
# done with 44 ,sdf loss is 0.006681161257438362 , using 28.26 seconds
# done with 45 ,sdf loss is 0.016303546633571385 , using 24.67 seconds
# done with 46 ,sdf loss is 0.003390123415738344 , using 24.42 seconds
# done with 47 ,sdf loss is 0.011647023586556315 , using 24.6 seconds
# done with 48 ,sdf loss is 0.013800397794693709 , using 24.58 seconds
# done with 49 ,sdf loss is 0.013118382822722197 , using 24.38 seconds
# done with 50 ,sdf loss is 0.02352151134982705 , using 24.48 seconds
# done with 51 ,sdf loss is 0.008259205776266754 , using 24.21 seconds
# done with 52 ,sdf loss is 0.017447145469486714 , using 24.46 seconds
# done with 53 ,sdf loss is 0.007929400121793152 , using 24.33 seconds
# done with 54 ,sdf loss is 0.002729933895170689 , using 24.46 seconds
# done with 55 ,sdf loss is 0.003509292984381318 , using 24.44 seconds
# done with 56 ,sdf loss is 0.006507378909736872 , using 24.48 seconds
# done with 57 ,sdf loss is 0.014621991524472832 , using 24.53 seconds
# done with 58 ,sdf loss is 0.0069469254929572346 , using 24.41 seconds
# done with 59 ,sdf loss is 0.014155742060393096 , using 24.38 seconds
# done with 60 ,sdf loss is 0.008207480749115348 , using 24.42 seconds
# done with 61 ,sdf loss is 0.0033306258032098413 , using 24.42 seconds
# done with 62 ,sdf loss is 0.004718317766673863 , using 24.18 seconds
# done with 63 ,sdf loss is 0.0011409795843064785 , using 24.2 seconds
# done with 64 ,sdf loss is 0.003112379985395819 , using 24.51 seconds
# done with 65 ,sdf loss is 0.006577169382944703 , using 24.26 seconds
# done with 66 ,sdf loss is 0.004945850512012839 , using 24.39 seconds
# done with 67 ,sdf loss is 0.0022360633593052626 , using 24.36 seconds
# done with 68 ,sdf loss is 0.007285551074892283 , using 24.38 seconds
# done with 69 ,sdf loss is 0.005090163880959153 , using 24.3 seconds
# done with 70 ,sdf loss is 0.0011855801159981639 , using 24.09 seconds
# done with 71 ,sdf loss is 0.000720450037624687 , using 24.46 seconds
# done with 72 ,sdf loss is 0.0015882698236964643 , using 24.19 seconds
# done with 73 ,sdf loss is 0.0018341560615226626 , using 24.25 seconds
# done with 74 ,sdf loss is 0.0028665268095210195 , using 24.09 seconds
# done with 75 ,sdf loss is 0.001601173501694575 , using 24.1 seconds
# done with 76 ,sdf loss is 0.000649519421858713 , using 24.27 seconds
# done with 77 ,sdf loss is 0.00018794981151586397 , using 24.02 seconds
# done with 78 ,sdf loss is 0.001733600487932563 , using 24.09 seconds
# done with 79 ,sdf loss is 0.0008791449887212366 , using 24.14 seconds
# done with 80 ,sdf loss is 0.004564640996977687 , using 24.06 seconds
# done with 81 ,sdf loss is 0.0026685142191126944 , using 24.1 seconds
# done with 82 ,sdf loss is 0.0014598991721868515 , using 24.0 seconds
# done with 83 ,sdf loss is 0.0005419965425971895 , using 24.14 seconds
# done with 84 ,sdf loss is 0.0004119876364711672 , using 24.16 seconds
# done with 85 ,sdf loss is 0.0015297783655114471 , using 24.03 seconds
# done with 86 ,sdf loss is 0.000660010305000469 , using 24.16 seconds
# done with 87 ,sdf loss is 0.00030906978936400263 , using 24.14 seconds
# done with 88 ,sdf loss is 0.00032206060423050075 , using 23.91 seconds
# done with 89 ,sdf loss is 0.0002561490851803683 , using 24.09 seconds
# done with 90 ,sdf loss is 0.0002917501900810748 , using 24.12 seconds
# done with 91 ,sdf loss is 0.00022152425663080066 , using 23.99 seconds
# done with 92 ,sdf loss is 0.002748340042307973 , using 23.97 seconds
# done with 93 ,sdf loss is 0.0011948810832109302 , using 24.55 seconds
# done with 94 ,sdf loss is 6.715723211527802e-05 , using 24.04 seconds
# done with 95 ,sdf loss is 0.0001067975717887748 , using 23.95 seconds
# done with 96 ,sdf loss is 0.0004844858922297135 , using 23.99 seconds
# done with 97 ,sdf loss is 0.00010932592704193667 , using 24.01 seconds
# done with 98 ,sdf loss is 4.357658799563069e-05 , using 23.86 seconds
# done with 99 ,sdf loss is 0.0027104761684313416 , using 24.01 seconds

# %%
# save weights model

# model_json = model_output_w.to_json()
# with open("model_w.json", "w") as json_file:
#     json_file.write(model_json)
# model.save_weights("model.h5")

# %%
# read data

# with open("model_w.json", "r") as json_file:
#     mode_s = model_from_json(json_file.read())
# mode_s.load_weights("model.h5")

# %% [markdown]
# ## Result Analysis

# %% [markdown]
# #### the trend of loss function

# %%
plt.plot(np.log(sdf_loss))

# %% [markdown]
# #### Training Set

# %%
# training set condition
print(model_output_w.predict([train_macro[:,:], train_micro[:, :, :]]).shape)
train_weights = model_output_w.predict([train_macro[:,:], train_micro[:, :, :]])
train_weights = 1/(1+np.exp(-train_weights))
# train_yield = train_weights
train_daily_return = (train_weights/train_weights.sum(axis=1).reshape(-1,1) * train_return).sum(axis=1)
print(train_daily_return.mean(), train_daily_return.std(), train_daily_return.shape)

benchmark = train_return.mean(axis=1)
plt.figure(figsize=(10,5))
plt.plot(np.cumprod(1+train_daily_return), color='red',label='sdf')
plt.plot(np.cumprod(1+benchmark), color='blue',label='benchmark')
plt.legend()
plt.grid()
plt.show()

print(train_daily_return.mean()/train_daily_return.std()*np.sqrt(252), benchmark.mean()/benchmark.std()*np.sqrt(252))
# Out:
# (2000, 50)
# 0.0008463972423223041 0.01516360934919789 (2000,)
# 0.8860779364541511 0.9017959790826483

# %% [markdown]
# #### Validation Set

# %%
# training set condition
print(model_output_w.predict([validation_macro[:,:], validation_micro[:, :, :]]).shape)
validation_weights = model_output_w.predict([validation_macro[:,:], validation_micro[:, :, :]])
validation_weights = 1/(1+np.exp(-validation_weights))
# train_yield = train_weights
validation_daily_return = (validation_weights/validation_weights.sum(axis=1).reshape(-1,1) * validation_return).sum(axis=1)
print(validation_daily_return.mean(), validation_daily_return.std(), validation_daily_return.shape)

benchmark = validation_return.mean(axis=1)
plt.figure(figsize=(10,6))
plt.plot(np.cumprod(1+validation_daily_return), color='red',label='sdf')
plt.plot(np.cumprod(1+benchmark), color='blue',label='benchmark')
plt.legend()
plt.grid()
plt.show()

print(validation_daily_return.mean()/validation_daily_return.std()*np.sqrt(252), benchmark.mean()/benchmark.std()*np.sqrt(252))
# Out:
# (599, 50)
# 0.0008261133603563225 0.016636942878265414 (599,)
# 0.7882543766280927 0.4787371457592317

# %% [markdown]
# #### Test Set

# %%
# training set condition
print(model_output_w.predict([test_macro[:,:], test_micro[:, :, :]]).shape)
test_weights = model_output_w.predict([test_macro[:,:], test_micro[:, :, :]])
test_weights = 1/(1+np.exp(-test_weights))
# train_yield = train_weights
test_daily_return = (test_weights/test_weights.sum(axis=1).reshape(-1,1) * test_return).sum(axis=1)
print(test_daily_return.mean(), test_daily_return.std(), test_daily_return.shape)

benchmark = test_return.mean(axis=1)
plt.figure(figsize=(10,6))
plt.plot(np.cumprod(1+test_daily_return), color='red',label='sdf')
plt.plot(np.cumprod(1+benchmark), color='blue',label='benchmark')
plt.legend()
plt.grid()
plt.show()

print(test_daily_return.mean()/test_daily_return.std()*np.sqrt(252), benchmark.mean()/benchmark.std()*np.sqrt(252))
# Out:
# (631, 50)
# -5.784622651230649e-05 0.01216329306743284 (631,)
# -0.07549603324687922 0.07604166641622334
